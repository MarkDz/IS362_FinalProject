# %% [markdown]
# # IS 362 - Final Project
# ## by Marek Dziwirek and Melanie Pruneda
#
#
# ![FDNY logo](images/fdny_logo.jpeg)
#
# ### Analyzing FDNY Data from NYC Open Data
#
# For our final project, we analyze three datasets from [NYC Open Data](https://opendata.cityofnewyork.us "NYC Open Data") relating to the Fire Department of New York.  Using "FDNY Firehouse Listing", "Incidents Responded to by Fire Companies", and "FDNY Monthly Response Times" we will answer the following questions:
# - [Q1 Where are the Manhattan firehouses located?](#Q1:-Where-are-the-Manhattan-firehouses-located?)
# - [Q2 What is the distribution of firehouses by borough?](#Q2:-What-is-the-distribution-of-firehouses-by-borough?)
# - [Q3 What were the top 5 most common incident types reported in 2017?](#Q3:-What-were-the-top-5-most-common-incident-types-reported-in-2017?)
# - [Q4 What is the distribution of the incidents in 2017 by borough?](#Q4:-What-is-the-distribution-of-the-incidents-in-2017-by-borough?)
# - [Q5 How many building fire incidents were there in 2017?](#Q5:-How-many-building-fire-incidents-were-there-in-2017?)
# - [Q6 What is the percentage by borough of the building fire incidents in 2017?](#Q6:-What-is-the-percentage-by-borough-of-the-building-fire-incidents-in-2017?)
# - [Q7 What is the FDNY average response time by borough?](#Q7:-What-is-the-FDNY-average-response-time-by-borough?)
#
# **We begin by importing necessary libraries, reading in the FDNY Firehouse Listing, and displaying the top 5 lines.  We see that data includes facility names, addresses and latitude and longitude coordinates.**

# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import folium
# %matplotlib inline

# reads data from csv and save in variable
firehouse = pd.read_csv("FDNY_Firehouse_Listing.csv")
firehouse.head()
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
#
#      Borough  Postcode   Latitude  Longitude  Community Board  \
# 0  Manhattan   10005.0  40.703466 -74.007538              1.0
# 1  Manhattan   10006.0  40.710072 -74.012523              1.0
# 2  Manhattan   10038.0  40.710048 -74.005245              1.0
# 3  Manhattan   10007.0  40.715463 -74.005938              1.0
# 4  Manhattan   10013.0  40.719759 -74.006678              1.0
#
#    Community Council  Census Tract        BIN            BBL  \
# 0                 1.0            7  1,000,867  1,000,350,001
# 1                 1.0           13  1,075,700  1,000,520,022
# 2                 1.0        1,501  1,001,287  1,000,930,030
# 3                 1.0           33  1,001,647  1,001,500,025
# 4                 1.0           33  1,002,150  1,001,890,035
#
#                                                  NTA
# 0  Battery Park City-Lower Manhattan             ...
# 1  Battery Park City-Lower Manhattan             ...
# 2  Battery Park City-Lower Manhattan             ...
# 3  SoHo-TriBeCa-Civic Center-Little Italy        ...
# 4  SoHo-TriBeCa-Civic Center-Little Italy        ...

# %% [markdown]
# **Next, we filter the data to display only firehouses located in the borough of Manhattan and display the top 10 lines.**

# %%
# filters column 'Borough' and displays rows that only match Manhattan
FDNY_Manhattan = firehouse[firehouse['Borough'].str.match('Manhattan')]
FDNY_Manhattan.head(10)
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
# 5                                  Engine 9/Ladder 6        75 Canal Street
# 6                    Engine 15/Ladder 18/Battalion 4         25 Pitt Street
# 7                                Engine 28/Ladder 11    222 East 2nd Street
# 8                                           Engine 5   340 East 14th Street
# 9                                          Engine 55      363 Broome Street
#
#      Borough  Postcode   Latitude  Longitude  Community Board  \
# 0  Manhattan   10005.0  40.703466 -74.007538              1.0
# 1  Manhattan   10006.0  40.710072 -74.012523              1.0
# 2  Manhattan   10038.0  40.710048 -74.005245              1.0
# 3  Manhattan   10007.0  40.715463 -74.005938              1.0
# 4  Manhattan   10013.0  40.719759 -74.006678              1.0
# 5  Manhattan   10002.0  40.715213 -73.992901              3.0
# 6  Manhattan   10002.0  40.716395 -73.983478              3.0
# 7  Manhattan   10009.0  40.721682 -73.982622              3.0
# 8  Manhattan   10003.0  40.731752 -73.983536              3.0
# 9  Manhattan   10013.0  40.720033 -73.995689              2.0
#
#    Community Council  Census Tract        BIN            BBL  \
# 0                 1.0            7  1,000,867  1,000,350,001
# 1                 1.0           13  1,075,700  1,000,520,022
# 2                 1.0        1,501  1,001,287  1,000,930,030
# 3                 1.0           33  1,001,647  1,001,500,025
# 4                 1.0           33  1,002,150  1,001,890,035
# 5                 1.0           16  1,003,898  1,003,000,030
# 6                 1.0           12  1,004,078  1,003,420,060
# 7                 2.0        2,202  1,004,608  1,003,850,058
# 8                 2.0           40  1,006,520  1,004,550,028
# 9                 1.0           41  1,066,722  1,004,700,012
#
#                                                  NTA
# 0  Battery Park City-Lower Manhattan             ...
# 1  Battery Park City-Lower Manhattan             ...
# 2  Battery Park City-Lower Manhattan             ...
# 3  SoHo-TriBeCa-Civic Center-Little Italy        ...
# 4  SoHo-TriBeCa-Civic Center-Little Italy        ...
# 5  Chinatown                                     ...
# 6  Lower East Side                               ...
# 7  Lower East Side                               ...
# 8  East Village                                  ...
# 9  SoHo-TriBeCa-Civic Center-Little Italy        ...

# %% [markdown]
# **We check to see whether any columns contain null values.**

# %%
FDNY_Manhattan.isnull().any()
# Out:
# FacilityName          False
# FacilityAddress       False
# Borough               False
# Postcode               True
# Latitude               True
# Longitude              True
# Community Board        True
# Community Council      True
# Census Tract           True
# BIN                    True
# BBL                    True
# NTA                    True
# dtype: bool

# %% [markdown]
# **Next, we drop any rows that contain NaN values and confirm that no columns contain null values.**

# %%
FDNY = FDNY_Manhattan.dropna(axis=0, how='any')
FDNY.isnull().any()
# Out:
# FacilityName          False
# FacilityAddress       False
# Borough               False
# Postcode              False
# Latitude              False
# Longitude             False
# Community Board       False
# Community Council     False
# Census Tract          False
# BIN                   False
# BBL                   False
# NTA                   False
# dtype: bool

# %% [markdown]
# **With clean data we can use latitude and longtitude data to indicate every firehouse in the borough of Manhattan.**

# %%
# creates a list of latitude and longtitude that help iterate over the data
locations = FDNY[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist[7]
# Out:
# [40.721682, -73.98262199999999]

# %% [markdown]
# **We use the `folium` module to create an interactive map to answer the question:**
#
# ## Q1: Where are the Manhattan firehouses located?

# %%
map = folium.Map(location=[40.7, -73.9], zoom_start=12)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=FDNY['FacilityName'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ***
# **Next, we use a simple count to display the number of firehouses by borough.**

# %%
# counts firehouses by Borough
firehouse_by_boro = firehouse.groupby('Borough').Borough.count()
firehouse_by_boro
# Out:
# Borough
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# Name: Borough, dtype: int64

# %% [markdown]
# **Next, we use a bar graph to answer the question:**
#
# ## Q2: What is the distribution of firehouses by borough?

# %%
firehouse_by_boro.plot.bar()

# %% [markdown]
# ***
#
# **Now we move on to analyzing Incidents Responded to by Fire Companies.  This dataset contains over 2 million rows and includes column listings such as incident date and time, incident type description, and borough. We perform various data tidying tasks to make it more manageable.**

# %%
# reads data from csv and save in variable
incidents = pd.read_csv("Incidents_Responded_to_by_Fire_Companies.csv", low_memory=False)
incidents.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692     0818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other  01/01/2013 12:00:20 AM
# 1  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:00:37 AM
# 2                  300 - Rescue, EMS incident, other  01/01/2013 12:01:17 AM
# 3                412 - Gas leak (natural gas or LPG)  01/01/2013 12:02:32 AM
# 4  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:01:49 AM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  01/01/2013 12:14:23 AM            1.0      01/01/2013 12:20:06 AM
# 1  01/01/2013 12:09:03 AM            3.0      01/01/2013 12:30:06 AM
# 2  01/01/2013 12:04:55 AM            1.0      01/01/2013 12:15:18 AM
# 3  01/01/2013 12:07:48 AM            4.0      01/01/2013 12:40:11 AM
# 4  01/01/2013 12:06:27 AM            6.0      01/01/2013 12:24:56 AM
#
#                                   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0  1 - More than initial alarm, less than Signal 7-5                   1186.0
# 1  1 - More than initial alarm, less than Signal 7-5                   1769.0
# 2  1 - More than initial alarm, less than Signal 7-5                    841.0
# 3  1 - More than initial alarm, less than Signal 7-5                   2259.0
# 4  1 - More than initial alarm, less than Signal 7-5                   1387.0
#
#                                   ACTION_TAKEN1_DESC  \
# 0                           00 - Action taken, other
# 1                                   86 - Investigate
# 2                           00 - Action taken, other
# 3  44 - Hazardous materials leak control & contai...
# 4                                   86 - Investigate
#
#               ...             ZIP_CODE   BOROUGH_DESC FLOOR  \
# 0             ...                10454      2 - Bronx   NaN
# 1             ...                10036  1 - Manhattan   NaN
# 2             ...                11418     5 - Queens   NaN
# 3             ...                11103     5 - Queens     1
# 4             ...                11385     5 - Queens   NaN
#
#   CO_DETECTOR_PRESENT_DESC FIRE_ORIGIN_BELOW_GRADE_FLAG  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#   STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC DETECTOR_PRESENCE_DESC  \
# 0                     NaN              NaN                    NaN
# 1                     NaN              NaN                    NaN
# 2                     NaN              NaN                    NaN
# 3                     NaN              NaN                    NaN
# 4                     NaN              NaN                    NaN
#
#    AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **In order to work with the data, we need to check each column for data types.**

# %%
# checks for data types
incidents.dtypes
# Out:
# IM_INCIDENT_KEY                   int64
# FIRE_BOX                         object
# INCIDENT_TYPE_DESC               object
# INCIDENT_DATE_TIME               object
# ARRIVAL_DATE_TIME                object
# UNITS_ONSCENE                   float64
# LAST_UNIT_CLEARED_DATE_TIME      object
# HIGHEST_LEVEL_DESC               object
# TOTAL_INCIDENT_DURATION         float64
# ACTION_TAKEN1_DESC               object
# ACTION_TAKEN2_DESC               object
# ACTION_TAKEN3_DESC               object
# PROPERTY_USE_DESC                object
# STREET_HIGHWAY                   object
# ZIP_CODE                         object
# BOROUGH_DESC                     object
# FLOOR                            object
# CO_DETECTOR_PRESENT_DESC         object
# FIRE_ORIGIN_BELOW_GRADE_FLAG    float64
# STORY_FIRE_ORIGIN_COUNT         float64
# FIRE_SPREAD_DESC                 object
# DETECTOR_PRESENCE_DESC           object
# AES_PRESENCE_DESC                object
# STANDPIPE_SYS_PRESENT_FLAG      float64
# dtype: object

# %% [markdown]
# **We want to filter our data to display incidents within a specific time period. Since the incident_date_time column data is object type, we convert it to datetime type for filtering.  Then we display the last 5 rows.**

# %%
# converts string to datetime type
incidents['INCIDENT_DATE_TIME'] = pd.to_datetime(incidents['INCIDENT_DATE_TIME'])
incidents.tail()
# Out:
#          IM_INCIDENT_KEY FIRE_BOX  \
# 2277774         62589520     2225
# 2277775         62589522     3757
# 2277776         62589542      715
# 2277777         62589549      936
# 2277778         62589556     1031
#
#                                         INCIDENT_TYPE_DESC  \
# 2277774                  300 - Rescue, EMS incident, other
# 2277775  735B - Unnecessary alarm/alarm system testing ...
# 2277776  745A - Unnecessary alarm/ordinary household ac...
# 2277777  735A - Unwarranted alarm/defective condition o...
# 2277778  735A - Unwarranted alarm/defective condition o...
#
#          INCIDENT_DATE_TIME ARRIVAL_DATE_TIME  UNITS_ONSCENE  \
# 2277774 2017-12-27 12:06:29               NaN            NaN
# 2277775 2017-12-27 12:08:21               NaN            NaN
# 2277776 2017-12-27 12:05:10               NaN            NaN
# 2277777 2017-12-27 12:13:40               NaN            NaN
# 2277778 2017-12-27 12:19:51               NaN            NaN
#
#         LAST_UNIT_CLEARED_DATE_TIME  \
# 2277774      12/27/2017 12:23:57 PM
# 2277775      12/27/2017 12:25:33 PM
# 2277776      12/27/2017 12:32:09 PM
# 2277777      12/27/2017 12:25:36 PM
# 2277778      12/27/2017 12:39:15 PM
#
#                                         HIGHEST_LEVEL_DESC  \
# 2277774  1 - More than initial alarm, less than Signal 7-5
# 2277775  1 - More than initial alarm, less than Signal 7-5
# 2277776  1 - More than initial alarm, less than Signal 7-5
# 2277777  1 - More than initial alarm, less than Signal 7-5
# 2277778  1 - More than initial alarm, less than Signal 7-5
#
#          TOTAL_INCIDENT_DURATION        ACTION_TAKEN1_DESC  \
# 2277774                   1048.0  00 - Action taken, other
# 2277775                   1032.0          86 - Investigate
# 2277776                   1619.0          86 - Investigate
# 2277777                    716.0          86 - Investigate
# 2277778                   1164.0          86 - Investigate
#
#                     ...             ZIP_CODE   BOROUGH_DESC FLOOR  \
# 2277774             ...                10455      2 - Bronx   NaN
# 2277775             ...                10463      2 - Bronx   NaN
# 2277776             ...                10016  1 - Manhattan   NaN
# 2277777             ...                10022  1 - Manhattan   NaN
# 2277778             ...                10021  1 - Manhattan   NaN
#
#         CO_DETECTOR_PRESENT_DESC FIRE_ORIGIN_BELOW_GRADE_FLAG  \
# 2277774                      NaN                          NaN
# 2277775                      NaN                          NaN
# 2277776                      NaN                          NaN
# 2277777                      NaN                          NaN
# 2277778                      NaN                          NaN
#
#         STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC DETECTOR_PRESENCE_DESC  \
# 2277774                     NaN              NaN                    NaN
# 2277775                     NaN              NaN                    NaN
# 2277776                     NaN              NaN                    NaN
# 2277777                     NaN              NaN                    NaN
# 2277778                     NaN              NaN                    NaN
#
#          AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 2277774                NaN                         NaN
# 2277775                NaN                         NaN
# 2277776                NaN                         NaN
# 2277777                NaN                         NaN
# 2277778                NaN                         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **We verify that the data has been changed to the desired type.**

# %%
incidents.dtypes
# Out:
# IM_INCIDENT_KEY                          int64
# FIRE_BOX                                object
# INCIDENT_TYPE_DESC                      object
# INCIDENT_DATE_TIME              datetime64[ns]
# ARRIVAL_DATE_TIME                       object
# UNITS_ONSCENE                          float64
# LAST_UNIT_CLEARED_DATE_TIME             object
# HIGHEST_LEVEL_DESC                      object
# TOTAL_INCIDENT_DURATION                float64
# ACTION_TAKEN1_DESC                      object
# ACTION_TAKEN2_DESC                      object
# ACTION_TAKEN3_DESC                      object
# PROPERTY_USE_DESC                       object
# STREET_HIGHWAY                          object
# ZIP_CODE                                object
# BOROUGH_DESC                            object
# FLOOR                                   object
# CO_DETECTOR_PRESENT_DESC                object
# FIRE_ORIGIN_BELOW_GRADE_FLAG           float64
# STORY_FIRE_ORIGIN_COUNT                float64
# FIRE_SPREAD_DESC                        object
# DETECTOR_PRESENCE_DESC                  object
# AES_PRESENCE_DESC                       object
# STANDPIPE_SYS_PRESENT_FLAG             float64
# dtype: object

# %% [markdown]
# **Now that our data is properly converted we can filter it. We choose to filter the data and select only incidents that occurred in 2017, displaying the top 10 rows.**

# %%
ts = pd.to_datetime('1/1/2017')
oneyear = incidents.loc[incidents.INCIDENT_DATE_TIME >= ts, :]
oneyear.head(10)
# Out:
#          IM_INCIDENT_KEY FIRE_BOX  \
# 1809424         60840813      591
# 1809425         60840819     8874
# 1809426         60840821     3664
# 1809427         60840822     2207
# 1809428         60840824      926
# 1809429         60840825     1493
# 1809430         60840826     4213
# 1809431         60840827      325
# 1809432         60840829     1021
# 1809433         60840831      765
#
#                                         INCIDENT_TYPE_DESC  \
# 1809424  735A - Unwarranted alarm/defective condition o...
# 1809425                  300 - Rescue, EMS incident, other
# 1809426                  300 - Rescue, EMS incident, other
# 1809427  735A - Unwarranted alarm/defective condition o...
# 1809428                   651 - Smoke scare, odor of smoke
# 1809429  735A - Unwarranted alarm/defective condition o...
# 1809430  745A - Unnecessary alarm/ordinary household ac...
# 1809431                   651 - Smoke scare, odor of smoke
# 1809432   353 - Removal of victim(s) from stalled elevator
# 1809433  735A - Unwarranted alarm/defective condition o...
#
#          INCIDENT_DATE_TIME       ARRIVAL_DATE_TIME  UNITS_ONSCENE  \
# 1809424 2017-01-01 00:00:22  01/01/2017 12:04:23 AM            3.0
# 1809425 2017-01-01 00:01:26  01/01/2017 12:06:24 AM            1.0
# 1809426 2017-01-01 00:02:38  01/01/2017 12:04:39 AM            1.0
# 1809427 2017-01-01 00:02:30  01/01/2017 12:06:06 AM            3.0
# 1809428 2017-01-01 00:02:31  01/01/2017 12:06:22 AM            3.0
# 1809429 2017-01-01 00:02:39  01/01/2017 12:07:10 AM            2.0
# 1809430 2017-01-01 00:02:52  01/01/2017 12:10:34 AM            2.0
# 1809431 2017-01-01 00:04:00  01/01/2017 12:06:49 AM            3.0
# 1809432 2017-01-01 00:04:45  01/01/2017 12:09:03 AM            1.0
# 1809433 2017-01-01 00:04:34  01/01/2017 12:07:44 AM            2.0
#
#         LAST_UNIT_CLEARED_DATE_TIME  \
# 1809424      01/01/2017 12:10:29 AM
# 1809425      01/01/2017 12:17:03 AM
# 1809426      01/01/2017 12:14:29 AM
# 1809427      01/01/2017 12:16:27 AM
# 1809428      01/01/2017 12:23:11 AM
# 1809429      01/01/2017 12:16:03 AM
# 1809430      01/01/2017 12:19:38 AM
# 1809431      01/01/2017 12:10:10 AM
# 1809432      01/01/2017 12:35:23 AM
# 1809433      01/01/2017 12:09:13 AM
#
#                                         HIGHEST_LEVEL_DESC  \
# 1809424  1 - More than initial alarm, less than Signal 7-5
# 1809425  1 - More than initial alarm, less than Signal 7-5
# 1809426  1 - More than initial alarm, less than Signal 7-5
# 1809427  1 - More than initial alarm, less than Signal 7-5
# 1809428  1 - More than initial alarm, less than Signal 7-5
# 1809429  1 - More than initial alarm, less than Signal 7-5
# 1809430  1 - More than initial alarm, less than Signal 7-5
# 1809431  1 - More than initial alarm, less than Signal 7-5
# 1809432  1 - More than initial alarm, less than Signal 7-5
# 1809433  1 - More than initial alarm, less than Signal 7-5
#
#          TOTAL_INCIDENT_DURATION        ACTION_TAKEN1_DESC  \
# 1809424                    607.0          86 - Investigate
# 1809425                    937.0  00 - Action taken, other
# 1809426                    711.0  00 - Action taken, other
# 1809427                    837.0          86 - Investigate
# 1809428                   1240.0  00 - Action taken, other
# 1809429                    804.0          86 - Investigate
# 1809430                   1006.0          86 - Investigate
# 1809431                    370.0  00 - Action taken, other
# 1809432                   1838.0     64 - Shut down system
# 1809433                    279.0          86 - Investigate
#
#                     ...             ZIP_CODE       BOROUGH_DESC FLOOR  \
# 1809424             ...                11217       4 - Brooklyn   NaN
# 1809425             ...                11436         5 - Queens   NaN
# 1809426             ...                10312  3 - Staten Island   NaN
# 1809427             ...                10451          2 - Bronx   NaN
# 1809428             ...                11213       4 - Brooklyn   NaN
# 1809429             ...                10027      1 - Manhattan   NaN
# 1809430             ...                11379         5 - Queens     1
# 1809431             ...                11211       4 - Brooklyn   NaN
# 1809432             ...                10021      1 - Manhattan    24
# 1809433             ...                10302  3 - Staten Island   NaN
#
#         CO_DETECTOR_PRESENT_DESC FIRE_ORIGIN_BELOW_GRADE_FLAG  \
# 1809424                      NaN                          NaN
# 1809425                      NaN                          NaN
# 1809426                      NaN                          NaN
# 1809427                      NaN                          NaN
# 1809428                      NaN                          NaN
# 1809429                      NaN                          NaN
# 1809430                      NaN                          NaN
# 1809431                      NaN                          NaN
# 1809432                      NaN                          NaN
# 1809433                      NaN                          NaN
#
#         STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC DETECTOR_PRESENCE_DESC  \
# 1809424                     NaN              NaN                    NaN
# 1809425                     NaN              NaN                    NaN
# 1809426                     NaN              NaN                    NaN
# 1809427                     NaN              NaN                    NaN
# 1809428                     NaN              NaN                    NaN
# 1809429                     NaN              NaN                    NaN
# 1809430                     NaN              NaN                    NaN
# 1809431                     NaN              NaN                    NaN
# 1809432                     NaN              NaN                    NaN
# 1809433                     NaN              NaN                    NaN
#
#          AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 1809424                NaN                         NaN
# 1809425                NaN                         NaN
# 1809426                NaN                         NaN
# 1809427                NaN                         NaN
# 1809428                NaN                         NaN
# 1809429                NaN                         NaN
# 1809430                NaN                         NaN
# 1809431                NaN                         NaN
# 1809432                NaN                         NaN
# 1809433                NaN                         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# **Now, we count all the incidents and look for most common incident type reported in 2017.**

# %%
incident_count = oneyear.groupby('INCIDENT_TYPE_DESC').INCIDENT_TYPE_DESC.count().sort_values(ascending=False)
incident_count.head(30)
# Out:
# INCIDENT_TYPE_DESC
# 300 - Rescue, EMS incident, other                               169096
# 651 - Smoke scare, odor of smoke                                 28013
# 353 - Removal of victim(s) from stalled elevator                 26455
# 412 - Gas leak (natural gas or LPG)                              24225
# 710 - Malicious, mischievous false call, other                   23326
# 735A - Unwarranted alarm/defective condition of alarm system     22968
# 522 - Water or steam leak                                        19493
# 113 - Cooking fire, confined to container                        17838
# 555 - Defective elevator, no occupants                           11454
# 736 - CO detector activation due to malfunction                   9512
# 322 - Motor vehicle accident with injuries                        9266
# 445 - Arcing, shorted electrical equipment                        7466
# 323 - Motor vehicle/pedestrian accident (MV Ped)                  6185
# 740A - Unnecessary alarm/construction activities                  6178
# 611 - Dispatched & canceled en route                              6093
# 5001 - Cable / Telephone Wires Down                               5609
# 151 - Outside rubbish, trash or waste fire                        5310
# 331 - Lock-in (if lock out , use 511 )                            4818
# 745A - Unnecessary alarm/ordinary household activities            4527
# 311 - Medical assist, assist EMS crew                             4484
# 600 - Good intent call, other                                     4260
# 511 - Lock-out                                                    3789
# 735B - Unnecessary alarm/alarm system testing or servicing        3412
# 200 - Overpressure rupture, explosion, overheat other             2999
# 500 - Service Call, other                                         2949
# 111 - Building fire                                               2301
# 4001 - Tree/branch removal or cutting                             2204
# 424 - Carbon monoxide incident                                    2170
# 746 - Carbon monoxide detector activation, no CO                  2048
# 118 - Trash or rubbish fire, contained                            1962
# Name: INCIDENT_TYPE_DESC, dtype: int64

# %% [markdown]
# **Now we use a horizontal bar chart to visualize the answer to the question:**
#
# ## Q3: What were the top 5 most common incident types reported in 2017?

# %%
incident_count.head().plot.barh(colormap='gist_rainbow').invert_yaxis()
plt.ylabel('Incident Type')
plt.xlabel('Count')
plt.title('Top 5 Types of FDNY Incidents in 2017')
# Out:
# Text(0.5,1,'Top 5 Types of FDNY Incidents in 2017')

# %% [markdown]
# ***
#
# **Next, we count all the incidents and sort them by borough and use a bar chart to visualize the answer to the question:**
#
# ## Q4: What is the distribution of the incidents in 2017 by borough?

# %%
incidents_by_boro = oneyear.groupby('BOROUGH_DESC')['INCIDENT_TYPE_DESC'].count().sort_values(ascending=False)
incidents_by_boro.plot(kind='bar', stacked=True, colormap='Paired')
plt.suptitle('Total Incidents by Borough')
plt.xlabel('Borough')
plt.ylabel('# of Incidents')

graph_incidents_by_boro = pd.DataFrame(incidents_by_boro)
graph_incidents_by_boro
# Out:
#                    INCIDENT_TYPE_DESC
# BOROUGH_DESC
# 4 - Brooklyn                   137628
# 1 - Manhattan                  118410
# 5 - Queens                      94528
# 2 - Bronx                       93760
# 3 - Staten Island               24029

# %% [markdown]
# ***
#
# **Next, we filter our data again and select only 'Building fire' incidents that occurred in 2017, displaying the top 10 rows.**

# %%
# filters incident type description column for 'Building fire' incidents
Fire = oneyear[oneyear['INCIDENT_TYPE_DESC'].str.match('111 - Building fire')]
Fire.head(10)
# Out:
#          IM_INCIDENT_KEY FIRE_BOX   INCIDENT_TYPE_DESC  INCIDENT_DATE_TIME  \
# 1809477         60840937     4221  111 - Building fire 2017-01-01 00:26:34
# 1809714         60841739     1253  111 - Building fire 2017-01-01 03:07:19
# 1809883         60842334     9269  111 - Building fire 2017-01-01 06:08:36
# 1810187         60843298     9350  111 - Building fire 2017-01-01 12:34:37
# 1810193         60843323     3315  111 - Building fire 2017-01-01 12:37:50
# 1810271         60843600     7831  111 - Building fire 2017-01-01 13:59:19
# 1810868         60845494     3178  111 - Building fire 2017-01-01 22:11:59
# 1811061         60846090      214  111 - Building fire 2017-01-02 03:46:29
# 1811370         60847108     4707  111 - Building fire 2017-01-02 12:32:58
# 1811627         60847920      889  111 - Building fire 2017-01-02 16:29:46
#
#               ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 1809477  01/01/2017 12:30:06 AM           15.0      01/01/2017 03:35:00 AM
# 1809714  01/01/2017 03:10:15 AM            6.0      01/01/2017 03:20:06 AM
# 1809883  01/01/2017 06:12:57 AM            6.0      01/01/2017 06:59:54 AM
# 1810187  01/01/2017 12:37:33 PM            7.0      01/01/2017 01:38:17 PM
# 1810193  01/01/2017 12:39:50 PM            6.0      01/01/2017 01:05:15 PM
# 1810271  01/01/2017 02:02:36 PM           11.0      01/01/2017 04:49:07 PM
# 1810868  01/01/2017 10:14:41 PM            6.0      01/01/2017 10:29:24 PM
# 1811061  01/02/2017 03:48:46 AM           13.0      01/02/2017 06:04:31 AM
# 1811370  01/02/2017 12:35:17 PM           13.0      01/02/2017 02:18:04 PM
# 1811627  01/02/2017 04:35:46 PM            6.0      01/02/2017 05:42:29 PM
#
#                                         HIGHEST_LEVEL_DESC  \
# 1809477                                     7 - Signal 7-5
# 1809714                                  0 - Initial alarm
# 1809883                                     7 - Signal 7-5
# 1810187                                     7 - Signal 7-5
# 1810193  1 - More than initial alarm, less than Signal 7-5
# 1810271                                     7 - Signal 7-5
# 1810868  1 - More than initial alarm, less than Signal 7-5
# 1811061                                     7 - Signal 7-5
# 1811370  1 - More than initial alarm, less than Signal 7-5
# 1811627                                     7 - Signal 7-5
#
#          TOTAL_INCIDENT_DURATION  \
# 1809477                  11306.0
# 1809714                    767.0
# 1809883                   3078.0
# 1810187                   3820.0
# 1810193                   1645.0
# 1810271                  10188.0
# 1810868                   1045.0
# 1811061                   8282.0
# 1811370                   6306.0
# 1811627                   4363.0
#
#                                     ACTION_TAKEN1_DESC  \
# 1809477  11 - Extinguishment by fire service personnel
# 1809714  11 - Extinguishment by fire service personnel
# 1809883  11 - Extinguishment by fire service personnel
# 1810187  11 - Extinguishment by fire service personnel
# 1810193  11 - Extinguishment by fire service personnel
# 1810271  11 - Extinguishment by fire service personnel
# 1810868  11 - Extinguishment by fire service personnel
# 1811061  11 - Extinguishment by fire service personnel
# 1811370  11 - Extinguishment by fire service personnel
# 1811627  11 - Extinguishment by fire service personnel
#
#                     ...             ZIP_CODE       BOROUGH_DESC  \
# 1809477             ...                10461          2 - Bronx
# 1809714             ...                10305  3 - Staten Island
# 1809883             ...                11435         5 - Queens
# 1810187             ...                11368         5 - Queens
# 1810193             ...                11229       4 - Brooklyn
# 1810271             ...                11372         5 - Queens
# 1810868             ...                10457          2 - Bronx
# 1811061             ...                10002      1 - Manhattan
# 1811370             ...                11436         5 - Queens
# 1811627             ...                99999      1 - Manhattan
#
#                  FLOOR CO_DETECTOR_PRESENT_DESC FIRE_ORIGIN_BELOW_GRADE_FLAG  \
# 1809477            NaN                      NaN                          NaN
# 1809714            NaN                      NaN                          NaN
# 1809883            NaN                      NaN                          1.0
# 1810187            3rd                      NaN                          NaN
# 1810193              1                      NaN                          NaN
# 1810271            NaN                      NaN                          NaN
# 1810868  2 B2 Stairway                      NaN                          NaN
# 1811061            NaN                      NaN                          NaN
# 1811370            5th                      NaN                          NaN
# 1811627             29                      NaN                          NaN
#
#         STORY_FIRE_ORIGIN_COUNT                    FIRE_SPREAD_DESC  \
# 1809477                     1.0  4 - Confined to building of origin
# 1809714                     5.0    1 - Confined to object of origin
# 1809883                     0.0      2 - Confined to room of origin
# 1810187                     3.0      2 - Confined to room of origin
# 1810193                     1.0    1 - Confined to object of origin
# 1810271                     3.0     3 - Confined to floor of origin
# 1810868                     2.0     3 - Confined to floor of origin
# 1811061                     3.0      2 - Confined to room of origin
# 1811370                     4.0  4 - Confined to building of origin
# 1811627                    29.0      2 - Confined to room of origin
#
#         DETECTOR_PRESENCE_DESC  AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 1809477       N - None present   N - None Present                         0.0
# 1809714            1 - Present   N - None Present                         0.0
# 1809883       N - None present   N - None Present                         0.0
# 1810187       N - None present   N - None Present                         0.0
# 1810193            1 - Present   N - None Present                         0.0
# 1810271            1 - Present   N - None Present                         0.0
# 1810868       N - None present   N - None Present                         1.0
# 1811061       N - None present   N - None Present                         0.0
# 1811370            1 - Present        1 - Present                         1.0
# 1811627            1 - Present        1 - Present                         1.0
#
# [10 rows x 24 columns]

# %% [markdown]
# **Using `count()` will give us the answer to the question:**
#
# ## Q5: How many building fire incidents were there in 2017?

# %%
Fire['INCIDENT_TYPE_DESC'].count()
# Out:
# 2301

# %% [markdown]
# ***
#
# **We can now count building fire occurrence by borough, renaming the columns for clearer results.**

# %%
building_fire = Fire.groupby('BOROUGH_DESC').size().reset_index()
building_fire.columns = building_fire.columns.map(str)
bf = building_fire.rename(columns={'BOROUGH_DESC':'Borough', '0': 'Fire_Incidents'})
bf
# Out:
#              Borough  Fire_Incidents
# 0      1 - Manhattan             428
# 1          2 - Bronx             474
# 2  3 - Staten Island             119
# 3       4 - Brooklyn             728
# 4         5 - Queens             552

# %% [markdown]
# **Next we create the pie graph for building fire incidents in the five boroughs. The pie graph answers the question:**
#
# ## Q6: What is the percentage by borough of the building fire incidents in 2017?

# %%
labels = bf['Borough']
sizes = bf['Fire_Incidents']
colors = ['yellow', 'gold', 'blue', 'lightcoral','red']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
explode = (0, 0, 0, 0.2, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.tight_layout()
plt.title('Building Fire Incidents 2017 - Percentage by Borough')
plt.show()

# %% [markdown]
# ***
#
# **In our final analysis, we look at FDNY Monthly Response Times.  We read in the CSV and find that the data includes columns such as incident by borough and average response time.**

# %%
# reads csv data
response_all = pd.read_csv('FDNY_Monthly_Response_Times.csv')
response_all.head()
# Out:
#   YEARMONTH        INCIDENTCLASSIFICATION INCIDENTBOROUGH  INCIDENTCOUNT  \
# 0   2009/07  All Fire/Emergency Incidents        Citywide          40850
# 1   2009/07  All Fire/Emergency Incidents       Manhattan          10709
# 2   2009/07  All Fire/Emergency Incidents           Bronx           8137
# 3   2009/07  All Fire/Emergency Incidents   Staten Island           2205
# 4   2009/07  All Fire/Emergency Incidents        Brooklyn          11505
#
#   AVERAGERESPONSETIME
# 0               04:27
# 1               04:32
# 2               04:37
# 3               04:45
# 4               04:01

# %% [markdown]
# **We will only use and analyze the columns corresponding to incidents by borough and average response time.**

# %%
response = pd.read_csv('FDNY_Monthly_Response_Times.csv', usecols = ['INCIDENTBOROUGH','AVERAGERESPONSETIME'], index_col = 'INCIDENTBOROUGH')
response.head(6)
# Out:
#                 AVERAGERESPONSETIME
# INCIDENTBOROUGH
# Citywide                      04:27
# Manhattan                     04:32
# Bronx                         04:37
# Staten Island                 04:45
# Brooklyn                      04:01
# Queens                        04:43

# %% [markdown]
# **We can display the lowest average response time.**

# %%
response['AVERAGERESPONSETIME'].min()
# Out:
# '03:16'

# %% [markdown]
# **And the highest average response time.**

# %%
response['AVERAGERESPONSETIME'].max()
# Out:
# '07:06'

# %% [markdown]
# **We examine the datatype of the average response time column.**

# %%
response.dtypes
# Out:
# AVERAGERESPONSETIME    object
# dtype: object

# %% [markdown]
# **We convert the average response time data type to datetime.**

# %%
# convert AVERAGERESPONSETIME to datetime object
response['AVERAGERESPONSETIME'] = pd.to_datetime(response['AVERAGERESPONSETIME'])
response.dtypes
# Out:
# AVERAGERESPONSETIME    datetime64[ns]
# dtype: object

# %%
response.head(6)
# Out:
#                 AVERAGERESPONSETIME
# INCIDENTBOROUGH
# Citywide        2018-05-21 04:27:00
# Manhattan       2018-05-21 04:32:00
# Bronx           2018-05-21 04:37:00
# Staten Island   2018-05-21 04:45:00
# Brooklyn        2018-05-21 04:01:00
# Queens          2018-05-21 04:43:00

# %% [markdown]
# **After conversion, we subtract the current date to leave only the time value.**

# %%
response['AVERAGERESPONSETIME'] = response['AVERAGERESPONSETIME'] - pd.to_datetime('today')
response.head(6)
# Out:
#                 AVERAGERESPONSETIME
# INCIDENTBOROUGH
# Citywide                   04:27:00
# Manhattan                  04:32:00
# Bronx                      04:37:00
# Staten Island              04:45:00
# Brooklyn                   04:01:00
# Queens                     04:43:00

# %% [markdown]
# **We convert the minutes and seconds into total seconds, so that we get a numeric value for making calculations.**

# %%
response['AVERAGERESPONSETIME'] = response['AVERAGERESPONSETIME'].dt.total_seconds()
response.head(6)
# Out:
#                  AVERAGERESPONSETIME
# INCIDENTBOROUGH
# Citywide                     16020.0
# Manhattan                    16320.0
# Bronx                        16620.0
# Staten Island                17100.0
# Brooklyn                     14460.0
# Queens                       16980.0

# %%
averagetime = response.groupby('INCIDENTBOROUGH')['AVERAGERESPONSETIME'].mean().sort_values()
averagetime
# Out:
# INCIDENTBOROUGH
# Brooklyn         14640.824176
# Citywide         16353.461538
# Staten Island    16902.774725
# Manhattan        16947.032967
# Bronx            17112.774725
# Queens           17197.417582
# Name: AVERAGERESPONSETIME, dtype: float64

# %% [markdown]
# **We use a simple bar graph to visualize the answer to the question:**
#
# ## Q7: What is the FDNY average response time by borough?

# %%
plt.style.use("ggplot")
averagetime.plot.barh().invert_yaxis()
plt.ylabel('Borough')
plt.xlabel('Seconds')
plt.suptitle('Average Response Time by Borough')
# Out:
# Text(0.5,0.98,'Average Response Time by Borough')

# %% [markdown]
# **Since values in seconds might be easy to visualize but more difficult to comprehend, we convert the values back into a datetime format and then strip the date, leaving only the time.**

# %%
averagemin = pd.to_datetime(averagetime, unit = 's')
minutesonly = averagemin.dt.time
minutesonly
# Out:
# INCIDENTBOROUGH
# Brooklyn         04:04:00.824176
# Citywide         04:32:33.461538
# Staten Island    04:41:42.774725
# Manhattan        04:42:27.032967
# Bronx            04:45:12.774725
# Queens           04:46:37.417582
# Name: AVERAGERESPONSETIME, dtype: object
